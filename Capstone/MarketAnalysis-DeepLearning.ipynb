# %% [markdown]
# ## Stock Market Prediction Via NLP Sentiment Analysis

# %%
import pandas as pd

# %% [markdown]
# ### Load Data

# %%
cnbc_df = pd.read_csv('./data/cnbc_data_truncated.csv')
cnbc_df
# Out:
#            Date                                            Summary
# 0    2024-06-03  All three major averages wrapped up a solid mo...
# 1    2024-06-04  Paramount and Skydance have agreed to terms of...
# 2    2024-06-05  Elon Musk ordered Nvidia to send thousands of ...
# 3    2024-06-06  The S&P 500 and the Nasdaq Composite hit new r...
# 4    2024-06-07  The indexes closed with little movement Thursd...
# ..          ...                                                ...
# 101  2024-10-25  A federal judge has blocked the proposed merge...
# 102  2024-10-28  Futures are trading higher Monday morning, led...
# 103  2024-10-29  JPMorgan Chase filed lawsuits against customer...
# 104  2024-10-30  Alphabet reported third-quarter earnings resul...
# 105  2024-10-31  Starbucks CEO Brian Niccol plans to 'fundament...
#
# [106 rows x 2 columns]

# %%
stock_df = pd.read_csv('./data/stock_data_truncated.csv')
stock_df
# Out:
#      Unnamed: 0        Date     Open     High      Low    Close  Adj Close  \
# 0             0  2024-10-31  5775.34  5775.34  5702.86  5705.45    5705.45
# 1             1  2024-10-30  5832.65  5850.94  5811.28  5813.67    5813.67
# 2             2  2024-10-29  5819.68  5847.19  5802.17  5832.92    5832.92
# 3             3  2024-10-28  5833.93  5842.92  5823.08  5823.52    5823.52
# 4             4  2024-10-25  5826.75  5862.82  5799.98  5808.12    5808.12
# ..          ...         ...      ...      ...      ...      ...        ...
# 101         101  2024-06-07  5343.81  5375.08  5331.33  5346.99    5346.99
# 102         102  2024-06-06  5357.80  5362.35  5335.36  5352.96    5352.96
# 103         103  2024-06-05  5314.48  5354.16  5297.64  5354.03    5354.03
# 104         104  2024-06-04  5278.24  5298.80  5257.63  5291.34    5291.34
# 105         105  2024-06-03  5297.15  5302.11  5234.32  5283.40    5283.40
#
#          Volume
# 0    4425660000
# 1    3851120000
# 2    3879100000
# 3    3691280000
# 4    3501280000
# ..          ...
# 101  3692760000
# 102  3609990000
# 103  3591460000
# 104  3707900000
# 105  4046920000
#
# [106 rows x 8 columns]

# %%
merged_df = pd.merge(cnbc_df, stock_df, on="Date", how="inner")
merged_df.head()
# Out:
#          Date                                            Summary  Unnamed: 0  \
# 0  2024-06-03  All three major averages wrapped up a solid mo...         105
# 1  2024-06-04  Paramount and Skydance have agreed to terms of...         104
# 2  2024-06-05  Elon Musk ordered Nvidia to send thousands of ...         103
# 3  2024-06-06  The S&P 500 and the Nasdaq Composite hit new r...         102
# 4  2024-06-07  The indexes closed with little movement Thursd...         101
#
#       Open     High      Low    Close  Adj Close      Volume
# 0  5297.15  5302.11  5234.32  5283.40    5283.40  4046920000
# 1  5278.24  5298.80  5257.63  5291.34    5291.34  3707900000
# 2  5314.48  5354.16  5297.64  5354.03    5354.03  3591460000
# 3  5357.80  5362.35  5335.36  5352.96    5352.96  3609990000
# 4  5343.81  5375.08  5331.33  5346.99    5346.99  3692760000

# %%
merged_df['PctChg'] = merged_df['Close'].pct_change() * 100
merged_df = merged_df.dropna(subset=['PctChg']).reset_index(drop=True)
merged_df.head()
# Out:
#          Date                                            Summary  Unnamed: 0  \
# 0  2024-06-04  Paramount and Skydance have agreed to terms of...         104
# 1  2024-06-05  Elon Musk ordered Nvidia to send thousands of ...         103
# 2  2024-06-06  The S&P 500 and the Nasdaq Composite hit new r...         102
# 3  2024-06-07  The indexes closed with little movement Thursd...         101
# 4  2024-06-10  Stock futures slipped Monday morning after pol...         100
#
#       Open     High      Low    Close  Adj Close      Volume    PctChg
# 0  5278.24  5298.80  5257.63  5291.34    5291.34  3707900000  0.150282
# 1  5314.48  5354.16  5297.64  5354.03    5354.03  3591460000  1.184766
# 2  5357.80  5362.35  5335.36  5352.96    5352.96  3609990000 -0.019985
# 3  5343.81  5375.08  5331.33  5346.99    5346.99  3692760000 -0.111527
# 4  5341.22  5365.79  5331.52  5360.79    5360.79  3622280000  0.258089

# %%
merged_df['Label'] = (merged_df['PctChg'] >= 0).astype(int)
merged_df.head()
# Out:
#          Date                                            Summary  Unnamed: 0  \
# 0  2024-06-04  Paramount and Skydance have agreed to terms of...         104
# 1  2024-06-05  Elon Musk ordered Nvidia to send thousands of ...         103
# 2  2024-06-06  The S&P 500 and the Nasdaq Composite hit new r...         102
# 3  2024-06-07  The indexes closed with little movement Thursd...         101
# 4  2024-06-10  Stock futures slipped Monday morning after pol...         100
#
#       Open     High      Low    Close  Adj Close      Volume    PctChg  Label
# 0  5278.24  5298.80  5257.63  5291.34    5291.34  3707900000  0.150282      1
# 1  5314.48  5354.16  5297.64  5354.03    5354.03  3591460000  1.184766      1
# 2  5357.80  5362.35  5335.36  5352.96    5352.96  3609990000 -0.019985      0
# 3  5343.81  5375.08  5331.33  5346.99    5346.99  3692760000 -0.111527      0
# 4  5341.22  5365.79  5331.52  5360.79    5360.79  3622280000  0.258089      1

# %% [markdown]
# ### Establish Baseline

# %%
label_counts = merged_df['Label'].value_counts()
print(label_counts)
# Out:
# Label
# 1    61
# 0    44
# Name: count, dtype: int64

# %%
#The baseline is calculated by simply guessing the majority outcome.
baseline = 61/105
baseline
# Out:
# 0.580952380952381

# %% [markdown]
# ### Experiment with models and hyperparameters

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Download required NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Function to preprocess text using lemmatizing
def preprocess_with_lemmatizing(text):
    tokens = nltk.word_tokenize(text.lower())
    return " ".join([lemmatizer.lemmatize(word) for word in tokens if word.isalnum()])

# Apply preprocessing
merged_df['Summary_Lemmatized'] = merged_df['Summary'].apply(preprocess_with_lemmatizing)

# Tokenization
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(merged_df['Summary_Lemmatized'])
sequences = tokenizer.texts_to_sequences(merged_df['Summary_Lemmatized'])
padded_sequences = pad_sequences(sequences, maxlen=100, padding='post', truncating='post')

# Encode labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(merged_df['Label'])
# Out:
# [nltk_data] Downloading package punkt to /Users/odeanmaye/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/odeanmaye/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/odeanmaye/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# %%
# Build the model
model = Sequential([
    Embedding(input_dim=5000, output_dim=128, input_length=100),
    Bidirectional(LSTM(64, return_sequences=True)),
    Bidirectional(LSTM(32, return_sequences=True)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/20
# /usr/local/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 17
#      15 # Train the model
#      16 early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
# ---> 17 model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), callbacks=[early_stopping])
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/nn.py:694, in binary_crossentropy(target, output, from_logits)
#     691 output = tf.convert_to_tensor(output)
#     693 if len(target.shape) != len(output.shape):
# --> 694     raise ValueError(
#     695         "Arguments `target` and `output` must have the same rank "
#     696         "(ndim). Received: "
#     697         f"target.shape={target.shape}, output.shape={output.shape}"
#     698     )
#     699 for e1, e2 in zip(target.shape, output.shape):
#     700     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Arguments `target` and `output` must have the same rank (ndim). Received: target.shape=(None,), output.shape=(None, 100, 1)

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4286 - loss: 0.7123
# Test Accuracy: 0.4285714328289032

# %%
model.save('text_classification_model.h5')

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5).astype(int)
# Out:
#       Preprocessing              Classifier Best Parameters  Accuracy  \
# 0   CountVectorizer      LogisticRegression              {}  0.628205
# 1   CountVectorizer  DecisionTreeClassifier              {}  0.602564
# 2   CountVectorizer           MultinomialNB              {}  0.564103
# 3   TfidfVectorizer      LogisticRegression              {}  0.641026
# 4   TfidfVectorizer  DecisionTreeClassifier              {}  0.589744
# 5   TfidfVectorizer           MultinomialNB              {}  0.666667
# 6   CountVectorizer      LogisticRegression              {}  0.641026
# 7   CountVectorizer  DecisionTreeClassifier              {}  0.717949
# 8   CountVectorizer           MultinomialNB              {}  0.538462
# 9   TfidfVectorizer      LogisticRegression              {}  0.641026
# 10  TfidfVectorizer  DecisionTreeClassifier              {}  0.564103
# 11  TfidfVectorizer           MultinomialNB              {}  0.679487
#
#                                                Report
# 0                 precision    recall  f1-score   ...
# 1                 precision    recall  f1-score   ...
# 2                 precision    recall  f1-score   ...
# 3                 precision    recall  f1-score   ...
# 4                 precision    recall  f1-score   ...
# 5                 precision    recall  f1-score   ...
# 6                 precision    recall  f1-score   ...
# 7                 precision    recall  f1-score   ...
# 8                 precision    recall  f1-score   ...
# 9                 precision    recall  f1-score   ...
# 10                precision    recall  f1-score   ...
# 11                precision    recall  f1-score   ...
